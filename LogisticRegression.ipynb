# %% [markdown]
# # Logistic Regression
# #### it is a supervised learning algorithum used for classification

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/drive/MyDrive/DataSets/LogRegression/insurance_data.csv")

# %%
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
df.value_counts()
# Out:
# age  bought_insurance
# 18   0                   2
# 19   0                   1
# 61   1                   1
# 60   1                   1
# 58   1                   1
# 56   1                   1
# 55   1                   1
#      0                   1
# 54   1                   1
# 52   0                   1
# 50   1                   1
# 49   1                   1
# 47   1                   1
# 46   1                   1
# 45   1                   1
# 40   1                   1
# 29   0                   1
# 28   0                   1
# 27   0                   1
# 26   0                   1
# 25   1                   1
#      0                   1
# 23   0                   1
# 22   0                   1
# 21   0                   1
# 62   1                   1
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                 0
# bought_insurance    0
# dtype: int64

# %%
df.shape
# Out:
# (27, 2)

# %%
x = df.iloc[:,:1]

# %%
x.head()
# Out:
#    age
# 0   22
# 1   25
# 2   47
# 3   52
# 4   46

# %%
x.shape
# Out:
# (27, 1)

# %%
x.value_counts()
# Out:
# age
# 18     2
# 25     2
# 55     2
# 47     1
# 61     1
# 60     1
# 58     1
# 56     1
# 54     1
# 52     1
# 50     1
# 49     1
# 46     1
# 19     1
# 45     1
# 40     1
# 29     1
# 28     1
# 27     1
# 26     1
# 23     1
# 22     1
# 21     1
# 62     1
# dtype: int64

# %%
y = df.iloc[:,-1]

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: bought_insurance, dtype: int64

# %%
y.shape
# Out:
# (27,)

# %%
y.value_counts()
# Out:
# 1    14
# 0    13
# Name: bought_insurance, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression

# %%
m1 = LogisticRegression()

# %%
m1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred_m1 = m1.predict(x_test)
print(ypred_m1)
# Out:
# [1 0 1 1 1 0 1]

# %%
pred_m1 = m1.predict([[32]])
print(pred_m1)
# Out:
# [0]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
import pickle

# %%
pickle.dump(m1,open('m1.pkl','wb'))

# %%
pickle_m1 = pickle.load(open('m1.pkl','rb'))

# %%
pickle_pred = pickle_m1.predict([[32]])
print(pickle_pred)
# Out:
# [0]
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   "X does not have valid feature names, but"

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
cm = confusion_matrix(y_test,ypred_m1)
print(cm)
# Out:
# [[2 0]
#  [0 5]]

# %%
print(classification_report(y_test,ypred_m1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         5
#
#     accuracy                           1.00         7
#    macro avg       1.00      1.00      1.00         7
# weighted avg       1.00      1.00      1.00         7
